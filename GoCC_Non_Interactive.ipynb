# %% [markdown]
# <a href="https://colab.research.google.com/github/jc4v1/GoCC/blob/main/GoCC_Non_Interactive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **GoCC** abstract example

# %% [markdown]
# # Requerimientos

# %%
#Requisitos Instalaciones
# !pip install pm4py
# !apt-get install graphviz -y
# !pip install graphviz networkx
# !apt-get -y update
# !apt-get -y install graphviz texlive-latex-extra texlive-pictures poppler-utils
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 12.2 MB/s eta 0:00:00
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# graphviz is already the newest version (2.42.2-6ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [85.0 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,909 kB]
# ...

# %%
# Imports

from pm4py.objects.bpmn.importer import importer as bpmn_importer
from pm4py.visualization.bpmn import visualizer as bpmn_vis
from IPython.display import Image, display
from pm4py.objects.conversion.bpmn import converter as bpmn_converter
from pm4py.visualization.petri_net import visualizer as pn_vis
from graphviz import Digraph
import os
import subprocess, os
from PIL import Image
from IPython.display import Image as IPImage, display
import os, random
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, clear_output, Image as IPImage

from pm4py.objects.bpmn.importer import importer as bpmn_importer
from pm4py.objects.conversion.bpmn import converter as bpmn_converter

from pm4py.algo.simulation.playout.petri_net import algorithm as playout
from pm4py.algo.conformance.alignments.petri_net import algorithm as alignments
from pm4py.visualization.petri_net import visualizer as pn_vis

# %% [markdown]
# # Modelos  (Inputs)

# %% [markdown]
# ### BPMN

# %%
bpmn_xml = r'''<?xml version="1.0" encoding="UTF-8"?><definitions xmlns="http://www.omg.org/spec/BPMN/20100524/MODEL" xmlns:bpmndi="http://www.omg.org/spec/BPMN/20100524/DI" xmlns:i18n="http://www.omg.org/spec/BPMN/non-normative/extensions/i18n/1.0" xmlns:omgdc="http://www.omg.org/spec/DD/20100524/DC" xmlns:omgdi="http://www.omg.org/spec/DD/20100524/DI" xmlns:signavio="http://www.signavio.com" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" exporter="Signavio Process Editor, http://www.signavio.com" exporterVersion="26.7.1-20260216143645+fc1d001" expressionLanguage="http://www.w3.org/TR/XPath" id="sid-67020268-ff2b-4b5f-9b31-5f77a07257fc" targetNamespace="http://www.signavio.com" typeLanguage="http://www.w3.org/2001/XMLSchema" xsi:schemaLocation="http://www.omg.org/spec/BPMN/20100524/MODEL http://www.omg.org/spec/BPMN/2.0/20100501/BPMN20.xsd">
   <process id="sid-883bb0c0-cfd2-49ee-a68f-9276ab550a07" isClosed="false" isExecutable="false" processType="None">
      <extensionElements>
         <signavio:signavioDiagramMetaData metaKey="revisionid" metaValue="8277c90d0cdd4c23bdeede5b67cb2062"/>
      </extensionElements>
      <task completionQuantity="1" id="sid-9F9DE677-1EA8-4452-8CAA-614119B917A5" isForCompensation="false" name="T10" startQuantity="1">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bgcolor" metaValue="#ffffcc"/>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
         <incoming>sid-43C1221B-DF2B-46D4-819D-EE59FD2E394A</incoming>
         <outgoing>sid-8CD9FD28-CA14-431A-95E1-0C461AECB8CD</outgoing>
      </task>
      <startEvent id="sid-6ACF054F-FE67-4978-93D6-5EF3B0F0A169" name="">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bgcolor" metaValue="#ffffff"/>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
         <outgoing>sid-43C1221B-DF2B-46D4-819D-EE59FD2E394A</outgoing>
      </startEvent>
      <task completionQuantity="1" id="sid-D7B29C42-7F9A-4887-A7E0-0FBBB38C16EB" isForCompensation="false" name="T9" startQuantity="1">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bgcolor" metaValue="#ffffcc"/>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
         <incoming>sid-4E7A0A67-7FD8-4A45-B9C2-811DBBBA6488</incoming>
         <outgoing>sid-D72E72C7-06F1-4558-BC40-8CD89BDB4F39</outgoing>
      </task>
      <task completionQuantity="1" id="sid-D2F96060-47E7-4851-BF9C-37CB6B943475" isForCompensation="false" name="T8" startQuantity="1">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bgcolor" metaValue="#ffffcc"/>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
         <incoming>sid-3F7DE156-D7E1-43FA-9587-2C42C3A0C19E</incoming>
         <outgoing>sid-70FC9D65-A1F9-4E59-AD1A-64CFD5CEBAB5</outgoing>
      </task>
      <task completionQuantity="1" id="sid-B9C8350B-8E78-4051-84B6-7B9A23E7FF71" isForCompensation="false" name="T7" startQuantity="1">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bgcolor" metaValue="#ffffcc"/>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
         <incoming>sid-13049DE9-7982-4AAD-BA19-B02E0B35CFAC</incoming>
         <outgoing>sid-6DA4A22F-7CD4-4608-94B2-23FC9A6FD572</outgoing>
      </task>
      <parallelGateway gatewayDirection="Diverging" id="sid-99DC08CB-DA80-4648-AC18-FBA99673D66A" name="">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bgcolor" metaValue="#ffffff"/>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
         <incoming>sid-8CD9FD28-CA14-431A-95E1-0C461AECB8CD</incoming>
         <outgoing>sid-13049DE9-7982-4AAD-BA19-B02E0B35CFAC</outgoing>
         <outgoing>sid-3F7DE156-D7E1-43FA-9587-2C42C3A0C19E</outgoing>
         <outgoing>sid-4E7A0A67-7FD8-4A45-B9C2-811DBBBA6488</outgoing>
      </parallelGateway>
      <parallelGateway gatewayDirection="Converging" id="sid-6509F999-026D-46A4-AF7F-B7A1802C7166" name="">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bgcolor" metaValue="#ffffff"/>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
         <incoming>sid-70FC9D65-A1F9-4E59-AD1A-64CFD5CEBAB5</incoming>
         <incoming>sid-D72E72C7-06F1-4558-BC40-8CD89BDB4F39</incoming>
         <incoming>sid-6DA4A22F-7CD4-4608-94B2-23FC9A6FD572</incoming>
         <outgoing>sid-BFC46F70-E934-4525-A04B-C59795ACAB07</outgoing>
      </parallelGateway>
      <exclusiveGateway gatewayDirection="Diverging" id="sid-3EBD9F42-CABF-4464-B894-68CDB3BC945E" name="">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bgcolor" metaValue="#ffffff"/>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
         <incoming>sid-5D9C88D7-EA6E-48F2-8247-696EEDC42CBD</incoming>
         <outgoing>sid-1AEF4000-C192-4757-B81D-CC7A60C61BD5</outgoing>
         <outgoing>sid-9697449D-C838-42CA-8425-FB8890DA316D</outgoing>
      </exclusiveGateway>
      <task completionQuantity="1" id="sid-80683CFA-C845-47D9-A584-D09E963E8637" isForCompensation="false" name="T6" startQuantity="1">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bgcolor" metaValue="#ffffcc"/>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
         <incoming>sid-1AEF4000-C192-4757-B81D-CC7A60C61BD5</incoming>
         <outgoing>sid-0768463E-5C3F-455A-97AF-CC5997E32903</outgoing>
      </task>
      <task completionQuantity="1" id="sid-6538463D-5C5F-4FA5-A97F-110A3DAC0261" isForCompensation="false" name="T11" startQuantity="1">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bgcolor" metaValue="#ffffcc"/>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
         <incoming>sid-9697449D-C838-42CA-8425-FB8890DA316D</incoming>
         <outgoing>sid-878BF222-B119-45A6-81EC-EE43D02B0C8E</outgoing>
      </task>
      <exclusiveGateway gatewayDirection="Converging" id="sid-B8F708E5-7D26-4A0B-A2D7-D3E11D168FA0" name="">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bgcolor" metaValue="#ffffff"/>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
         <incoming>sid-0768463E-5C3F-455A-97AF-CC5997E32903</incoming>
         <incoming>sid-878BF222-B119-45A6-81EC-EE43D02B0C8E</incoming>
         <outgoing>sid-188FE23E-89DB-49B0-A1AE-658F58B92020</outgoing>
      </exclusiveGateway>
      <exclusiveGateway gatewayDirection="Diverging" id="sid-606CCBFF-E50E-4132-A5B5-E3D957B08AF5" name="">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bgcolor" metaValue="#ffffff"/>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
         <incoming>sid-188FE23E-89DB-49B0-A1AE-658F58B92020</incoming>
         <outgoing>sid-E2D8907B-A05B-464E-8885-5AABF31DFAD7</outgoing>
         <outgoing>sid-DD587697-49AA-43C7-A870-9A705CE85994</outgoing>
      </exclusiveGateway>
      <endEvent id="sid-D2BA2456-2D12-47DF-9C84-CEEA05D769E8" name="">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bgcolor" metaValue="#ffffff"/>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
         <incoming>sid-E2D8907B-A05B-464E-8885-5AABF31DFAD7</incoming>
      </endEvent>
      <exclusiveGateway gatewayDirection="Converging" id="sid-223B5743-4ED0-41D8-BA86-95A30A7FA5FA" name="">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bgcolor" metaValue="#ffffff"/>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
         <incoming>sid-BFC46F70-E934-4525-A04B-C59795ACAB07</incoming>
         <incoming>sid-DD587697-49AA-43C7-A870-9A705CE85994</incoming>
         <outgoing>sid-5D9C88D7-EA6E-48F2-8247-696EEDC42CBD</outgoing>
      </exclusiveGateway>
      <sequenceFlow id="sid-43C1221B-DF2B-46D4-819D-EE59FD2E394A" name="" sourceRef="sid-6ACF054F-FE67-4978-93D6-5EF3B0F0A169" targetRef="sid-9F9DE677-1EA8-4452-8CAA-614119B917A5">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
      </sequenceFlow>
      <sequenceFlow id="sid-8CD9FD28-CA14-431A-95E1-0C461AECB8CD" name="" sourceRef="sid-9F9DE677-1EA8-4452-8CAA-614119B917A5" targetRef="sid-99DC08CB-DA80-4648-AC18-FBA99673D66A">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
      </sequenceFlow>
      <sequenceFlow id="sid-13049DE9-7982-4AAD-BA19-B02E0B35CFAC" name="" sourceRef="sid-99DC08CB-DA80-4648-AC18-FBA99673D66A" targetRef="sid-B9C8350B-8E78-4051-84B6-7B9A23E7FF71">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
      </sequenceFlow>
      <sequenceFlow id="sid-3F7DE156-D7E1-43FA-9587-2C42C3A0C19E" name="" sourceRef="sid-99DC08CB-DA80-4648-AC18-FBA99673D66A" targetRef="sid-D2F96060-47E7-4851-BF9C-37CB6B943475">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
      </sequenceFlow>
      <sequenceFlow id="sid-4E7A0A67-7FD8-4A45-B9C2-811DBBBA6488" name="" sourceRef="sid-99DC08CB-DA80-4648-AC18-FBA99673D66A" targetRef="sid-D7B29C42-7F9A-4887-A7E0-0FBBB38C16EB">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
      </sequenceFlow>
      <sequenceFlow id="sid-70FC9D65-A1F9-4E59-AD1A-64CFD5CEBAB5" name="" sourceRef="sid-D2F96060-47E7-4851-BF9C-37CB6B943475" targetRef="sid-6509F999-026D-46A4-AF7F-B7A1802C7166">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
      </sequenceFlow>
      <sequenceFlow id="sid-D72E72C7-06F1-4558-BC40-8CD89BDB4F39" name="" sourceRef="sid-D7B29C42-7F9A-4887-A7E0-0FBBB38C16EB" targetRef="sid-6509F999-026D-46A4-AF7F-B7A1802C7166">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
      </sequenceFlow>
      <sequenceFlow id="sid-6DA4A22F-7CD4-4608-94B2-23FC9A6FD572" name="" sourceRef="sid-B9C8350B-8E78-4051-84B6-7B9A23E7FF71" targetRef="sid-6509F999-026D-46A4-AF7F-B7A1802C7166">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
      </sequenceFlow>
      <sequenceFlow id="sid-1AEF4000-C192-4757-B81D-CC7A60C61BD5" name="" sourceRef="sid-3EBD9F42-CABF-4464-B894-68CDB3BC945E" targetRef="sid-80683CFA-C845-47D9-A584-D09E963E8637">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
      </sequenceFlow>
      <sequenceFlow id="sid-9697449D-C838-42CA-8425-FB8890DA316D" name="" sourceRef="sid-3EBD9F42-CABF-4464-B894-68CDB3BC945E" targetRef="sid-6538463D-5C5F-4FA5-A97F-110A3DAC0261">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
      </sequenceFlow>
      <sequenceFlow id="sid-0768463E-5C3F-455A-97AF-CC5997E32903" name="" sourceRef="sid-80683CFA-C845-47D9-A584-D09E963E8637" targetRef="sid-B8F708E5-7D26-4A0B-A2D7-D3E11D168FA0">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
      </sequenceFlow>
      <sequenceFlow id="sid-878BF222-B119-45A6-81EC-EE43D02B0C8E" name="" sourceRef="sid-6538463D-5C5F-4FA5-A97F-110A3DAC0261" targetRef="sid-B8F708E5-7D26-4A0B-A2D7-D3E11D168FA0">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
      </sequenceFlow>
      <sequenceFlow id="sid-188FE23E-89DB-49B0-A1AE-658F58B92020" name="" sourceRef="sid-B8F708E5-7D26-4A0B-A2D7-D3E11D168FA0" targetRef="sid-606CCBFF-E50E-4132-A5B5-E3D957B08AF5">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
      </sequenceFlow>
      <sequenceFlow id="sid-E2D8907B-A05B-464E-8885-5AABF31DFAD7" name="" sourceRef="sid-606CCBFF-E50E-4132-A5B5-E3D957B08AF5" targetRef="sid-D2BA2456-2D12-47DF-9C84-CEEA05D769E8">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
      </sequenceFlow>
      <sequenceFlow id="sid-BFC46F70-E934-4525-A04B-C59795ACAB07" name="" sourceRef="sid-6509F999-026D-46A4-AF7F-B7A1802C7166" targetRef="sid-223B5743-4ED0-41D8-BA86-95A30A7FA5FA">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
      </sequenceFlow>
      <sequenceFlow id="sid-5D9C88D7-EA6E-48F2-8247-696EEDC42CBD" name="" sourceRef="sid-223B5743-4ED0-41D8-BA86-95A30A7FA5FA" targetRef="sid-3EBD9F42-CABF-4464-B894-68CDB3BC945E">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
      </sequenceFlow>
      <sequenceFlow id="sid-DD587697-49AA-43C7-A870-9A705CE85994" name="" sourceRef="sid-606CCBFF-E50E-4132-A5B5-E3D957B08AF5" targetRef="sid-223B5743-4ED0-41D8-BA86-95A30A7FA5FA">
         <extensionElements>
            <signavio:signavioMetaData metaKey="bordercolor" metaValue="#000000"/>
         </extensionElements>
      </sequenceFlow>
   </process>
   <bpmndi:BPMNDiagram id="sid-2d3be9e5-0e6e-4e5f-b0b9-98bfa822b62c">
      <bpmndi:BPMNPlane bpmnElement="sid-883bb0c0-cfd2-49ee-a68f-9276ab550a07" id="sid-19baeb69-9817-4177-884f-2e776021a296">
         <bpmndi:BPMNShape bpmnElement="sid-9F9DE677-1EA8-4452-8CAA-614119B917A5" id="sid-9F9DE677-1EA8-4452-8CAA-614119B917A5_gui">
            <omgdc:Bounds height="80.0" width="99.99999999999999" x="79.99998293020612" y="129.99999806284907"/>
            <bpmndi:BPMNLabel labelStyle="sid-5143637e-ed9e-41a2-b6ef-685e09d95fa3">
               <omgdc:Bounds height="12.0" width="20.8285675048828" x="119.58569917776471" y="161.99999806284907"/>
            </bpmndi:BPMNLabel>
         </bpmndi:BPMNShape>
         <bpmndi:BPMNShape bpmnElement="sid-6ACF054F-FE67-4978-93D6-5EF3B0F0A169" id="sid-6ACF054F-FE67-4978-93D6-5EF3B0F0A169_gui">
            <omgdc:Bounds height="30.0" width="30.0" x="4.999982892953341" y="154.99999787658456"/>
         </bpmndi:BPMNShape>
         <bpmndi:BPMNShape bpmnElement="sid-D7B29C42-7F9A-4887-A7E0-0FBBB38C16EB" id="sid-D7B29C42-7F9A-4887-A7E0-0FBBB38C16EB_gui">
            <omgdc:Bounds height="80.0" width="100.0" x="304.99998356350545" y="224.99999832361937"/>
            <bpmndi:BPMNLabel labelStyle="sid-5143637e-ed9e-41a2-b6ef-685e09d95fa3">
               <omgdc:Bounds height="12.0" width="13.88571548461914" x="348.0571258211959" y="256.99999832361937"/>
            </bpmndi:BPMNLabel>
         </bpmndi:BPMNShape>
         <bpmndi:BPMNShape bpmnElement="sid-D2F96060-47E7-4851-BF9C-37CB6B943475" id="sid-D2F96060-47E7-4851-BF9C-37CB6B943475_gui">
            <omgdc:Bounds height="80.0" width="100.0" x="304.9999814773429" y="129.99999903142452"/>
            <bpmndi:BPMNLabel labelStyle="sid-5143637e-ed9e-41a2-b6ef-685e09d95fa3">
               <omgdc:Bounds height="12.0" width="13.88571548461914" x="348.0571237350333" y="161.99999903142452"/>
            </bpmndi:BPMNLabel>
         </bpmndi:BPMNShape>
         <bpmndi:BPMNShape bpmnElement="sid-B9C8350B-8E78-4051-84B6-7B9A23E7FF71" id="sid-B9C8350B-8E78-4051-84B6-7B9A23E7FF71_gui">
            <omgdc:Bounds height="80.0" width="100.0" x="304.99998356350545" y="30.000000894069665"/>
            <bpmndi:BPMNLabel labelStyle="sid-5143637e-ed9e-41a2-b6ef-685e09d95fa3">
               <omgdc:Bounds height="12.000000000000007" width="13.88571548461914" x="348.0571258211959" y="62.000000894069665"/>
            </bpmndi:BPMNLabel>
         </bpmndi:BPMNShape>
         <bpmndi:BPMNShape bpmnElement="sid-99DC08CB-DA80-4648-AC18-FBA99673D66A" id="sid-99DC08CB-DA80-4648-AC18-FBA99673D66A_gui">
            <omgdc:Bounds height="40.0" width="40.0" x="219.99998147734289" y="149.99999791383746"/>
         </bpmndi:BPMNShape>
         <bpmndi:BPMNShape bpmnElement="sid-6509F999-026D-46A4-AF7F-B7A1802C7166" id="sid-6509F999-026D-46A4-AF7F-B7A1802C7166_gui">
            <omgdc:Bounds height="40.0" width="39.99999999999994" x="449.99997793831716" y="149.9999967589975"/>
         </bpmndi:BPMNShape>
         <bpmndi:BPMNShape bpmnElement="sid-3EBD9F42-CABF-4464-B894-68CDB3BC945E" id="sid-3EBD9F42-CABF-4464-B894-68CDB3BC945E_gui" isMarkerVisible="true">
            <omgdc:Bounds height="40.0" width="40.0" x="619.9999805912378" y="149.99999791383746"/>
         </bpmndi:BPMNShape>
         <bpmndi:BPMNShape bpmnElement="sid-80683CFA-C845-47D9-A584-D09E963E8637" id="sid-80683CFA-C845-47D9-A584-D09E963E8637_gui">
            <omgdc:Bounds height="80.0" width="100.0" x="704.9999700859196" y="30.00000067055225"/>
            <bpmndi:BPMNLabel labelStyle="sid-5143637e-ed9e-41a2-b6ef-685e09d95fa3">
               <omgdc:Bounds height="12.0" width="13.88571548461914" x="748.05711234361" y="62.000000670552254"/>
            </bpmndi:BPMNLabel>
         </bpmndi:BPMNShape>
         <bpmndi:BPMNShape bpmnElement="sid-6538463D-5C5F-4FA5-A97F-110A3DAC0261" id="sid-6538463D-5C5F-4FA5-A97F-110A3DAC0261_gui">
            <omgdc:Bounds height="79.99999999999997" width="100.0" x="704.9999753385787" y="224.99999664723876"/>
            <bpmndi:BPMNLabel labelStyle="sid-5143637e-ed9e-41a2-b6ef-685e09d95fa3">
               <omgdc:Bounds height="12.0" width="20.828567504882812" x="744.5856915861373" y="256.99999664723873"/>
            </bpmndi:BPMNLabel>
         </bpmndi:BPMNShape>
         <bpmndi:BPMNShape bpmnElement="sid-B8F708E5-7D26-4A0B-A2D7-D3E11D168FA0" id="sid-B8F708E5-7D26-4A0B-A2D7-D3E11D168FA0_gui" isMarkerVisible="true">
            <omgdc:Bounds height="40.0" width="40.0" x="849.9999637529263" y="149.9999944791199"/>
         </bpmndi:BPMNShape>
         <bpmndi:BPMNShape bpmnElement="sid-606CCBFF-E50E-4132-A5B5-E3D957B08AF5" id="sid-606CCBFF-E50E-4132-A5B5-E3D957B08AF5_gui" isMarkerVisible="true">
            <omgdc:Bounds height="40.0" width="40.0" x="934.9999567866338" y="150.4999961115677"/>
         </bpmndi:BPMNShape>
         <bpmndi:BPMNShape bpmnElement="sid-D2BA2456-2D12-47DF-9C84-CEEA05D769E8" id="sid-D2BA2456-2D12-47DF-9C84-CEEA05D769E8_gui">
            <omgdc:Bounds height="28.0" width="28.0" x="1019.9999491870419" y="156.4999960668642"/>
         </bpmndi:BPMNShape>
         <bpmndi:BPMNShape bpmnElement="sid-223B5743-4ED0-41D8-BA86-95A30A7FA5FA" id="sid-223B5743-4ED0-41D8-BA86-95A30A7FA5FA_gui" isMarkerVisible="true">
            <omgdc:Bounds height="40.0" width="40.0" x="534.9999805872555" y="150.49999723288005"/>
         </bpmndi:BPMNShape>
         <bpmndi:BPMNEdge bpmnElement="sid-43C1221B-DF2B-46D4-819D-EE59FD2E394A" id="sid-43C1221B-DF2B-46D4-819D-EE59FD2E394A_gui">
            <omgdi:waypoint x="34.99998289295334" y="169.99999790198427"/>
            <omgdi:waypoint x="79.99998293020612" y="169.9999979781834"/>
         </bpmndi:BPMNEdge>
         <bpmndi:BPMNEdge bpmnElement="sid-8CD9FD28-CA14-431A-95E1-0C461AECB8CD" id="sid-8CD9FD28-CA14-431A-95E1-0C461AECB8CD_gui">
            <omgdi:waypoint x="179.9999829302061" y="170.22624234228908"/>
            <omgdi:waypoint x="219.99998147734289" y="170.40723775926705"/>
         </bpmndi:BPMNEdge>
         <bpmndi:BPMNEdge bpmnElement="sid-13049DE9-7982-4AAD-BA19-B02E0B35CFAC" id="sid-13049DE9-7982-4AAD-BA19-B02E0B35CFAC_gui">
            <omgdi:waypoint x="240.49998147734289" y="149.99999791383746"/>
            <omgdi:waypoint x="240.49998147734289" y="70.00000089406967"/>
            <omgdi:waypoint x="304.99998356350545" y="70.00000089406967"/>
         </bpmndi:BPMNEdge>
         <bpmndi:BPMNEdge bpmnElement="sid-3F7DE156-D7E1-43FA-9587-2C42C3A0C19E" id="sid-3F7DE156-D7E1-43FA-9587-2C42C3A0C19E_gui">
            <omgdi:waypoint x="259.9999814773429" y="170.41484526574092"/>
            <omgdi:waypoint x="304.9999814773429" y="170.21833915474895"/>
         </bpmndi:BPMNEdge>
         <bpmndi:BPMNEdge bpmnElement="sid-4E7A0A67-7FD8-4A45-B9C2-811DBBBA6488" id="sid-4E7A0A67-7FD8-4A45-B9C2-811DBBBA6488_gui">
            <omgdi:waypoint x="240.49998147734289" y="189.99999791383746"/>
            <omgdi:waypoint x="240.49998147734289" y="264.99999832361937"/>
            <omgdi:waypoint x="304.99998356350545" y="264.99999832361937"/>
         </bpmndi:BPMNEdge>
         <bpmndi:BPMNEdge bpmnElement="sid-70FC9D65-A1F9-4E59-AD1A-64CFD5CEBAB5" id="sid-70FC9D65-A1F9-4E59-AD1A-64CFD5CEBAB5_gui">
            <omgdi:waypoint x="404.9999814773429" y="170.2164482707723"/>
            <omgdi:waypoint x="449.99997793831716" y="170.41125257086492"/>
         </bpmndi:BPMNEdge>
         <bpmndi:BPMNEdge bpmnElement="sid-D72E72C7-06F1-4558-BC40-8CD89BDB4F39" id="sid-D72E72C7-06F1-4558-BC40-8CD89BDB4F39_gui">
            <omgdi:waypoint x="404.99998356350545" y="264.99999832361937"/>
            <omgdi:waypoint x="470.4999779383171" y="264.99999832361937"/>
            <omgdi:waypoint x="470.4999779383171" y="189.9999967589975"/>
         </bpmndi:BPMNEdge>
         <bpmndi:BPMNEdge bpmnElement="sid-6DA4A22F-7CD4-4608-94B2-23FC9A6FD572" id="sid-6DA4A22F-7CD4-4608-94B2-23FC9A6FD572_gui">
            <omgdi:waypoint x="404.99998356350545" y="70.00000089406967"/>
            <omgdi:waypoint x="470.4999779383171" y="70.00000089406967"/>
            <omgdi:waypoint x="470.4999779383171" y="149.9999967589975"/>
         </bpmndi:BPMNEdge>
         <bpmndi:BPMNEdge bpmnElement="sid-1AEF4000-C192-4757-B81D-CC7A60C61BD5" id="sid-1AEF4000-C192-4757-B81D-CC7A60C61BD5_gui">
            <omgdi:waypoint x="640.4999805912378" y="149.99999791383746"/>
            <omgdi:waypoint x="640.4999805912378" y="70.00000067055225"/>
            <omgdi:waypoint x="704.9999700859196" y="70.00000067055225"/>
         </bpmndi:BPMNEdge>
         <bpmndi:BPMNEdge bpmnElement="sid-9697449D-C838-42CA-8425-FB8890DA316D" id="sid-9697449D-C838-42CA-8425-FB8890DA316D_gui">
            <omgdi:waypoint x="640.4999805912378" y="189.99999791383746"/>
            <omgdi:waypoint x="640.4999805912378" y="264.99999664723873"/>
            <omgdi:waypoint x="704.9999753385787" y="264.99999664723873"/>
         </bpmndi:BPMNEdge>
         <bpmndi:BPMNEdge bpmnElement="sid-0768463E-5C3F-455A-97AF-CC5997E32903" id="sid-0768463E-5C3F-455A-97AF-CC5997E32903_gui">
            <omgdi:waypoint x="804.9999700859196" y="70.00000067055225"/>
            <omgdi:waypoint x="870.4999637529263" y="70.00000067055225"/>
            <omgdi:waypoint x="870.4999637529263" y="149.9999944791199"/>
         </bpmndi:BPMNEdge>
         <bpmndi:BPMNEdge bpmnElement="sid-878BF222-B119-45A6-81EC-EE43D02B0C8E" id="sid-878BF222-B119-45A6-81EC-EE43D02B0C8E_gui">
            <omgdi:waypoint x="804.9999753385787" y="264.99999664723873"/>
            <omgdi:waypoint x="870.4999637529263" y="264.99999664723873"/>
            <omgdi:waypoint x="870.4999637529263" y="189.9999944791199"/>
         </bpmndi:BPMNEdge>
         <bpmndi:BPMNEdge bpmnElement="sid-188FE23E-89DB-49B0-A1AE-658F58B92020" id="sid-188FE23E-89DB-49B0-A1AE-658F58B92020_gui">
            <omgdi:waypoint x="889.9999637529263" y="170.61470074537647"/>
            <omgdi:waypoint x="934.9999567866338" y="170.87940747268257"/>
         </bpmndi:BPMNEdge>
         <bpmndi:BPMNEdge bpmnElement="sid-E2D8907B-A05B-464E-8885-5AABF31DFAD7" id="sid-E2D8907B-A05B-464E-8885-5AABF31DFAD7_gui">
            <omgdi:waypoint x="974.9999567866338" y="170.87579226678278"/>
            <omgdi:waypoint x="1019.9999491870419" y="170.58916805799186"/>
         </bpmndi:BPMNEdge>
         <bpmndi:BPMNEdge bpmnElement="sid-BFC46F70-E934-4525-A04B-C59795ACAB07" id="sid-BFC46F70-E934-4525-A04B-C59795ACAB07_gui">
            <omgdi:waypoint x="489.9999779383171" y="170.61470274648997"/>
            <omgdi:waypoint x="534.9999805872555" y="170.8794088870546"/>
         </bpmndi:BPMNEdge>
         <bpmndi:BPMNEdge bpmnElement="sid-5D9C88D7-EA6E-48F2-8247-696EEDC42CBD" id="sid-5D9C88D7-EA6E-48F2-8247-696EEDC42CBD_gui">
            <omgdi:waypoint x="574.9999805872555" y="170.8852915067521"/>
            <omgdi:waypoint x="619.9999805912378" y="170.62058598489503"/>
         </bpmndi:BPMNEdge>
         <bpmndi:BPMNEdge bpmnElement="sid-DD587697-49AA-43C7-A870-9A705CE85994" id="sid-DD587697-49AA-43C7-A870-9A705CE85994_gui">
            <omgdi:waypoint x="955.4999567866338" y="150.4999961115677"/>
            <omgdi:waypoint x="955.4999567866338" y="12.0"/>
            <omgdi:waypoint x="555.4999805872555" y="12.0"/>
            <omgdi:waypoint x="555.4999805872555" y="150.49999723288005"/>
         </bpmndi:BPMNEdge>
      </bpmndi:BPMNPlane>
      <bpmndi:BPMNLabelStyle id="sid-5143637e-ed9e-41a2-b6ef-685e09d95fa3">
         <omgdc:Font isBold="false" isItalic="false" isStrikeThrough="false" isUnderline="false" name="Arial" size="12.0"/>
      </bpmndi:BPMNLabelStyle>
   </bpmndi:BPMNDiagram>
</definitions>'''

# %% [markdown]
# ### Goal Model (Modelling in Leaf 2.0) [Leaf 2.0](https://www.cs.utoronto.ca/~amgrubb/leaf-ui/Tool.html)

# %%
model_text = """
A a000 Actor1 A
A a001 Actor2 A

I a000 0000 S 6 Q1
I a000 0001 S 6 Q2
I a000 0002 G 6 G1
I a000 0003 T 6 T2
I a000 0004 T 6 T1
I -    0005 S 6 Q3
I -    0006 T 6 T3
I -    0007 G 6 G2
I a001 0008 T 6 T4
I a001 0009 T 5 T7
I a001 0010 T 5 T8
I a001 0011 T 5 T9
I a001 0012 T 5 T10
I a001 0013 S 6 Q4
I a001 0014 T 5 T5
I a001 0015 T 5 T6

L MAKES 0002 0001
L AND 0003 0002
L AND 0004 0002
L DEPENDS 0000 0005
L DEPENDS 0004 0006
L DEPENDS 0003 0007
L OR 0009 0008
L OR 0010 0008
L OR 0011 0008
L DEPENDS 0006 0008
L DEPENDS 0007 0012
L DEPENDS 0005 0013
L MAKES 0015 0013
L MAKES 0014 0013
L BREAKS 0008 0013
"""

# %% [markdown]
# #### Soft goal (shape)

# %%
# TikZ  en el código
tikz_tex = r"""
\documentclass[tikz,border=0pt]{standalone}
\usepackage{tikz}
\begin{document}
\tikzset{every picture/.style={line width=0.75pt}}
\begin{tikzpicture}[x=0.75pt,y=0.75pt,yscale=-1,xscale=1]

\draw   (90.73,72.5) .. controls (109.91,82.03) and (91.3,118.97) .. (75.61,108.04)
.. controls (59.92,97.12) and (63.98,114.87) .. (41.32,107.36)
.. controls (18.65,99.85) and (40.59,61) .. (57.59,73.22)
.. controls (74.6,85.43) and (71.54,62.97) .. (90.73,72.5) -- cycle ;

\node at (66,90) {\Large $T$};

\end{tikzpicture}
\end{document}
"""

workdir = "/content/tikz_shape"
os.makedirs(workdir, exist_ok=True)

tex_path = os.path.join(workdir, "shape.tex")
pdf_path = os.path.join(workdir, "shape.pdf")
png_base = os.path.join(workdir, "shape")
# this should be your generated file
png_path = "/content/tikz_shape/shape.png"

# output típico

with open(tex_path, "w", encoding="utf-8") as f:
    f.write(tikz_tex)

# Compila a PDF
subprocess.run(
    ["pdflatex", "-interaction=nonstopmode", "-halt-on-error", "shape.tex"],
    cwd=workdir, check=True
)

try:
    subprocess.run(
        ["pdftocairo", "-png", "-transp", "-r", "300", "-singlefile", pdf_path, png_base],
        cwd=workdir, check=True
    )
    png_path2 = os.path.join(workdir, "shape.png")
    if os.path.exists(png_path2):
        png_path = png_path2
except subprocess.CalledProcessError:

    subprocess.run(
        ["pdftocairo", "-png", "-transp", "-r", "300", pdf_path, png_base],
        cwd=workdir, check=True
    )

    if not os.path.exists(png_path):
        # por si acaso, busca cualquier png generado
        for fn in os.listdir(workdir):
            if fn.startswith("shape") and fn.endswith(".png"):
                png_path = os.path.join(workdir, fn)
                break

print("PNG generado:", png_path)
# Out:
# PNG generado: /content/tikz_shape/shape.png

# %%
in_path = "/content/tikz_shape/shape.png"
out_path = "/content/tikz_shape/shape_trim.png"

img = Image.open(in_path).convert("RGBA")
bbox = img.getbbox()  # bbox of non-zero pixels (works well for most cases)

# More robust trim: use alpha channel to find visible area
alpha = img.split()[-1]
bbox = alpha.getbbox()

trimmed = img.crop(bbox)
trimmed.save(out_path)

print("Saved trimmed PNG:", out_path)
# Out:
# Saved trimmed PNG: /content/tikz_shape/shape_trim.png

# %%
png_path = "/content/tikz_shape/shape_trim.png"

dot = Digraph(format="png")
dot.attr(rankdir="LR")

dot.node("A", "Actor", shape="circle")
dot.node("customT", label="", shape="none", image=png_path,
         fixedsize="true", width="1.6", height="0.8", imagescale="true")

dot.edge("A", "customT", label="DEPENDS")
display(IPImage(dot.pipe()))

# %% [markdown]
# # Pre-processing

# %%
# Clean BPMN
clean = bpmn_xml.lstrip("\ufeff \t\r\n")
first = clean.find("<?xml")
if first > 0:
    clean = clean[first:]

# Escribir el archivo
path = "/content/model2.bpmn"
with open(path, "w", encoding="utf-8", newline="") as f:
    f.write(clean)

print("Written:", path)
print("First 80 chars:", repr(open(path, "r", encoding="utf-8").read(80)))
# Out:
# Written: /content/model2.bpmn
# First 80 chars: '<?xml version="1.0" encoding="UTF-8"?><definitions xmlns="http://www.omg.org/spe'

# %%
# Visualize the model (BPMN) - SAP Signavio (for modelling)

bpmn_path = "/content/model2.bpmn"  #
bpmn_model = bpmn_importer.apply(bpmn_path)

gviz = bpmn_vis.apply(bpmn_model)

# Render como PNG
display(IPImage(gviz.pipe(format="png")))

# %% [markdown]
# # Petri nets

# %%
# Convert  BPMN to Petri net
# 1) Import BPMN (.bpmn or .xml)
bpmn_path = "/content/model2.bpmn"   #
bpmn_model = bpmn_importer.apply(bpmn_path)

# 2) Convert BPMN -> Petri net
# Returns (net, initial_marking, final_marking)
net, im, fm = bpmn_converter.apply(bpmn_model)

print("Places:", len(net.places))
print("Transitions:", len(net.transitions))
print("Arcs:", len(net.arcs))

# Optional: export Petri net to PNML
from pm4py.objects.petri_net.exporter import exporter as pnml_exporter
pnml_exporter.apply(net, im, "converted_net.pnml", final_marking=fm)
print("Saved PNML to converted_net.pnml")
# Out:
# Places: 12
# Transitions: 11
# Arcs: 26
# Saved PNML to converted_net.pnml

# %%
#Visualize Petri net


# --- Visualize Petri net ---
# Variants: pn_vis.Variants.WO_DECORATION (simple), pn_vis.Variants.FREQUENCY, pn_vis.Variants.PERFORMANCE (need log)
gviz = pn_vis.apply(net, im, fm, variant=pn_vis.Variants.WO_DECORATION)

# Show (opens a viewer window in many environments)
pn_vis.view(gviz)

# Or save to file (PNG/SVG/PDF depending on extension / backend)
pn_vis.save(gviz, "petri_net.png")
print("Saved visualization to petri_net.png")
# Out:
# Saved visualization to petri_net.png

# %% [markdown]
# # Rendering the goal model (Specification .leaf)

# %%
from graphviz import Digraph
import re

actors = {}     # actor_id -> actor_name
nodes = {}      # node_id  -> {label,type,actor_id}
edges = []      # (src, tgt, rel)

for raw in model_text.splitlines():
    line = raw.strip()
    if not line:
        continue
    parts = re.split(r"\s+", line)

    if parts[0] == "A" and len(parts) >= 3:
        actor_id = parts[1]
        actor_name = parts[2]
        actors[actor_id] = actor_name
        continue

    if parts[0] == "I" and len(parts) >= 6:
        _, actor_id, nid, typ, _lvl, label = parts[:6]
        nodes[nid] = {"label": label, "type": typ, "actor": actor_id}
        continue

    if parts[0] == "L" and len(parts) >= 4:
        _, rel, src, tgt = parts[:4]
        edges.append((src, tgt, rel))
        continue

# Unassigned bucket
UNASSIGNED = "_unassigned_"
if any(n["actor"] == "-" for n in nodes.values()):
    actors[UNASSIGNED] = "Unassigned"
    for nid, data in nodes.items():
        if data["actor"] == "-":
            data["actor"] = UNASSIGNED


dot = Digraph("istar_model2")
dot.attr(rankdir="LR", fontsize="12", labelloc="t", label="Model 2 (i*)")
dot.attr("node", fontsize="11")

shape_map = {"G": "ellipse", "T": "hexagon", "S": "doubleoctagon", "R": "note"}

edge_style = {
    "DEPENDS": {"style": "dashed"},
    "MAKES":   {"style": "solid"},
    "BREAKS":  {"style": "solid"},
    "AND":     {"style": "solid"},
    "OR":      {"style": "solid"},
}

for actor_id, actor_name in actors.items():
    is_unassigned = (actor_id == UNASSIGNED)

    with dot.subgraph(name=f"cluster_{actor_id}") as c:
        # boundary style
        if is_unassigned:
            c.attr(
                label="",                 # hide title (optional)
                color="transparent",      # no border
                bgcolor="transparent",    # no background
                penwidth="0"              # no outline thickness
            )
            # keep node outline normal in unassigned area
            c.attr("node", color="black")
        else:
            c.attr(label=actor_name, color="#66bb66", style="rounded")
            c.attr("node", color="#2e7d32")

        # nodes inside this actor
        for nid, data in nodes.items():
            if data["actor"] != actor_id:
                continue
            c.node(
                nid,
                label=data["label"],
                shape=shape_map.get(data["type"], "ellipse")
            )

# edges
for src, tgt, rel in edges:
    if src not in nodes or tgt not in nodes:
        continue
    st = edge_style.get(rel, {})
    dot.edge(src, tgt, label=rel, **st)

dot

# %% [markdown]
# # Key Concepts (Goal Models)
#
#
#
# ### Actors
#
# > **Actor** — a person, role, or organization that has intentions and participates in the system.
#
# ---
#
# ### Intentional Elements
#
# > **Goal** — something clear-cut that an actor wants to achieve.
#
# > **Task** — an action or step that an actor wants or must perform.
#
# > **Resource** — a thing (physical, informational, or skill-based) that an actor needs to possess, usually to perform a task.
#
# > **Soft Goal** — a goal an actor wants to achieve but with a fuzzy or non-binary satisfaction criterion.
# > Typically used to represent qualities or decision criteria.
#
#
# ---
#
# ### Links
#
# > **AND Decomposition** — to achieve the **parent**, **all children** must be achieved.
#
# > **OR Decomposition (Means–Ends)** — to achieve the **parent**, **one or more alternatives** (children) must be achieved.
#
# > **Dependency** — an **actor** depends on something from **another actor**, usually to achieve a **goal** or perform a **task**.
#
# > **Contribution** — an element in an actor has a **positive or negative effect** on a **soft goal**.  The effect can be **strongly positive (MAKES)**, or **strongly negative (BREAKS)**.
#
# ---
# ### Nodes
#
# > **Leaf Node** are defined as nodes with NO Incoming decomposition (AND/OR [Means-End]) or contribution links (Makes, Breaks, Helps, Hurts) and  NO Outgoing dependency links (Depends).
#
#
# > **Root (Top) Nodes** are defined as nodes with NO Outgoing decomposition (AND/OR [Means-End]) or contribution links (Makes, Breaks, Helps, Hurts) and NO Incoming dependency links (Depends).
#
#
# > **Transitive-children:** all nodes reachable downstream from Destination by repeatedly following contribution links of the specified type
#
#
# ---

# %% [markdown]
# # Satisfaction an propagation of intentional elements
#
# ---
# ## Decomposition Links
#
# ---
# ##### AND Decomposition
#
# | Child 1 | Child 2 | Parent |
# |--------|--------|--------|
# | Satisfied (⊤, ⊥) | Satisfied (⊤, ⊥) | Satisfied (⊤, ⊥) |
# | Satisfied (⊤, ⊥) | Pending (⊤, ⊤) | Pending (⊤, ⊤) |
# | Pending (⊤, ⊤) | Satisfied (⊤, ⊥) | Pending (⊤, ⊤) |
# | Pending (⊤, ⊤) | Pending (⊤, ⊤) | Pending (⊤, ⊤) |
# | Unknown | Unknown | Unknown |
# | Unknown | Pending (⊤, ⊤) | Pending (⊤, ⊤) |
# | Pending (⊤, ⊤) | Unknown | Pending (⊤, ⊤)  |
# | Unknown | Satisfied (⊤, ⊥) | Unknown |
# | Satisfied (⊤, ⊥) | Unknown | Unknown |
#
#
# ---
# ##### OR Decomposition
#
# | Child 1 | Child 2 | Parent |
# |--------|--------|--------|
# | Satisfied (⊤, ⊥) | Satisfied (⊤, ⊥) | Satisfied (⊤, ⊥) |
# | Satisfied (⊤, ⊥) | Pending (⊤, ⊤) | Satisfied (⊤, ⊥) |
# | Pending (⊤, ⊤) | Satisfied (⊤, ⊥) |Satisfied (⊤, ⊥) |
# | Pending (⊤, ⊤) | Pending (⊤, ⊤) | Pending (⊤, ⊤) |
# | Unknown | Unknown | Unknown |
# | Unknown | Pending (⊤, ⊤) | Pending (⊤, ⊤)|
# | Pending (⊤, ⊤) | Unknown | Pending (⊤, ⊤)|
# | Unknown | Satisfied (⊤, ⊥) |  Satisfied (⊤, ⊥)  |
# | Satisfied (⊤, ⊥) | Unknown |  Satisfied (⊤, ⊥) |
#
# ---
#
# ## Contribution Links
# ---
#
#
# > **Contribution propagation** — contribution links propagate according to the **type of contribution link**.  For example, a **Source MAKES Destination** propagates a strongly positive effect from Source to Destination.
#
#
# We distinguish two cases:
#
# - **Case A (Destination = Unknown):** the link can *set* the Destination.
# - **Case B (Destination ≠ Unknown):** the link may *force Pending* on parts of the downstream chain (your transitive-children rule).
#
# ---
#
# #### Case A — Destination is **Unknown**
#
# | Link Type | Source value | New Destination value |
# |----------|--------------|-----------------------|
# | MAKE  | Unknown | Unknown |
# | MAKE  | Satisfied $(\top,\bot)$ | Satisfied $(\top)$ |
# | MAKE  | Pending $(\top,\top)$ | Pending $(\top,\top)$ |
# | BREAK | Unknown | Unknown |
# | BREAK | Satisfied $(\top,\bot)$ | Denied $(\bot)$ |
# | BREAK | Pending $(\top,\top)$ | Pending $(\top,\top)$ |
#
# ---
#
# #### Case B — Destination already has a value (**Destination ≠ Unknown**)
#
# | Link Type | If Source is… | Destination becomes… | Extra rule (propagation to transitive-children) |
# |----------|----------------|----------------------|-----------------------------------------------|
# | MAKE  | Satisfied $(\top,\bot)$ | Satisfied $(\top)$ | Set **Pending $(\top,\top)$** for all Destination **transitive-children** along a **BREAK** chain |
# | BREAK | Satisfied $(\top,\bot)$ | Denied $(\bot)$ | Set **Pending $(\top,\top)$** for all Destination **transitive-children** along a **MAKE** chain |
# | MAKE / BREAK | Unknown | (no change) | none |
# | MAKE / BREAK | Pending $(\top,\top)$ | Pending $(\top,\top)$ | none |
#
# ---
#
# ## Dependency Links
#
# ---
#
# > **Dependency propagation** — dependency links propagate values in the **opposite direction** of the `depends` arrow.
# > If the **Destination depends on the Source**, then the label/value at the **Source** is propagated directly to the **Destination**.
#
# ### Dependency Propagation
#
# | Source value | Dependum value | Destination value |
# |--------------|----------------|-------------------|
# | Unknown | Unknown | Unknown |
# | Satisfied $(\top,\bot)$ | Satisfied $(\top,\bot)$ | Satisfied $(\top,\bot)$ |
# | Pending $(\top,\top)$ | Pending $(\top,\top)$ | Pending $(\top,\top)$ |

# %% [markdown]
# # Interactive Generator (Process Model - traces)

# %%
# !pip -q install pm4py ipywidgets
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.4 MB/s eta 0:00:00

# %%
import pickle

# %%
BPMN_PATH = "/content/model2.bpmn"
bpmn_model = bpmn_importer.apply(BPMN_PATH)
net, im, fm = bpmn_converter.apply(bpmn_model)

print("Loaded model ")
print("Places:", len(net.places), "Transitions:", len(net.transitions), "Arcs:", len(net.arcs))


# Helpers

def classify_move(move):
    log_mv, model_mv = move
    if log_mv == ">>" and model_mv != ">>":
        return "MODEL_MOVE"
    if model_mv == ">>" and log_mv != ">>":
        return "LOG_MOVE"
    if log_mv == model_mv and log_mv != ">>":
        return "SYNC_MOVE"
    return "OTHER"

def summarize_alignment(a):
    counts = {"SYNC_MOVE": 0, "LOG_MOVE": 0, "MODEL_MOVE": 0, "OTHER": 0}
    for mv in a.get("alignment", []):
        counts[classify_move(mv)] += 1
    return counts

def swap_adjacent_events(trace, rng, p_swap):
    i = 0
    while i < len(trace) - 1:
        if rng.random() < p_swap:
            trace[i], trace[i+1] = trace[i+1], trace[i]
            i += 2  # skip next to avoid immediate undo
        else:
            i += 1

def inject_noise_pm4py_log(log, rng, p_drop=0.0, p_insert=0.0, p_swap=0.0, insert_labels=None):
    insert_labels = insert_labels or ["NOISE"]

    for trace in log:
        # 1) drop
        kept = []
        for ev in trace:
            if rng.random() > p_drop:
                kept.append(ev)
        trace[:] = kept

        # 2) swap (after drop, before insert)
        if p_swap > 0.0 and len(trace) >= 2:
            swap_adjacent_events(trace, rng, p_swap)

        # 3) insert (by default, append at end)
        if rng.random() < p_insert:
            extra = rng.choice(insert_labels)
            trace.append({"concept:name": extra})

    return log

# Widgets

w_traces = widgets.IntSlider(value=20, min=1, max=500, step=1, description="#traces")
w_maxlen = widgets.IntSlider(value=10, min=5, max=500, step=5, description="max_len")
w_drop = widgets.FloatSlider(value=0.25, min=0.0, max=0.8, step=0.05, description="drop p") # remove event
w_insert = widgets.FloatSlider(value=0.30, min=0.0, max=0.8, step=0.05, description="insert p") # add event not in alphabet
w_swap = widgets.FloatSlider(value=0.00, min=0.0, max=0.8, step=0.05, description="swap p") #add vviolations in order of events
w_seed = widgets.IntText(value=1, description="seed")

btn_run = widgets.Button(description="Simulate + Align", button_style="primary")
btn_show_net = widgets.Button(description="Show Petri net")
w_case = widgets.IntSlider(value=0, min=0, max=0, step=1, description="case idx")
out = widgets.Output()

display(widgets.VBox([
    widgets.HBox([w_traces, w_maxlen, w_seed]),
    widgets.HBox([w_drop, w_insert, w_swap]),
    widgets.HBox([btn_run, btn_show_net]),
    w_case,
    out
]))

state = {}

def show_net():
    with out:
        clear_output()
        gviz = pn_vis.apply(net, im, fm, variant=pn_vis.Variants.WO_DECORATION)
        display(IPImage(gviz.pipe(format="png")))

def show_case(i):
    log = state.get("log")
    aligned = state.get("aligned")
    df = state.get("df")
    if log is None or aligned is None:
        return

    i = int(i)
    tr = log[i]
    a = aligned[i]

    display(df.head(12))

  # print("\n--- Trace events ---")
  #  print([ev["concept:name"] for ev in tr])

  #  print("\n--- Alignment summary ---")
  #  print({**{"fitness": a.get("fitness"), "cost": a.get("cost")}, **summarize_alignment(a)})

  # print("\n--- Moves (type, (log, model)) ---")
  #  for mv in a.get("alignment", []):
  #   print(f"{classify_move(mv):>10}  {mv}")

def on_run(_):
    with out:
        clear_output()

        rng = random.Random(int(w_seed.value))

        # simulate log from your net
        params = {
            "no_traces": int(w_traces.value),
            "max_trace_length": int(w_maxlen.value),
        }
        log = playout.apply(net, im, parameters=params)

        # noise (drop/insert/swap)
        if float(w_drop.value) > 0.0 or float(w_insert.value) > 0.0 or float(w_swap.value) > 0.0:
            model_labels = sorted({t.label for t in net.transitions if t.label is not None})
            insert_labels = (model_labels[:10] if model_labels else []) + ["NOISE"]
            inject_noise_pm4py_log(
                log, rng,
                p_drop=float(w_drop.value),
                p_insert=float(w_insert.value),
                p_swap=float(w_swap.value),
                insert_labels=insert_labels
            )

        # --- SAVE PYTHON LOG OBJECT ---
        pkl_path = "/content/log.pkl"
        with open(pkl_path, "wb") as f:
            pickle.dump(log, f)
        print("Saved Python log object to:", pkl_path)

        # alignments
        aligned = alignments.apply_log(log, net, im, fm)

        # summary table
        rows = []
        for idx, a in enumerate(aligned):
            counts = summarize_alignment(a)
            rows.append({
                "case": idx,
                "fitness": a.get("fitness"),
                "cost": a.get("cost"),
                **counts
            })
        df = pd.DataFrame(rows)

        state["log"] = log
        state["aligned"] = aligned
        state["df"] = df

        w_case.max = max(0, len(log) - 1)
        w_case.value = 0

        print("Done traces:", len(log))
        show_case(0)

def on_case_change(change):
    if change["name"] == "value" and state.get("aligned") is not None:
        with out:
            clear_output()
            show_case(change["new"])

btn_run.on_click(on_run)
btn_show_net.on_click(lambda _: show_net())
w_case.observe(on_case_change, names="value")
# Out:
# Loaded model
# Places: 12 Transitions: 11 Arcs: 26
# ...

# %% [markdown]
# # Visualizing Alignments

# %% [markdown]
# ![Skærmbillede 2026-02-23 135905.png](data:image/png;base64,...)

# %%
# Formateo de alignments viaulization

def mv_to_str(mv):
    """Convert PM4Py move objects to readable strings."""
    if mv == ">>":
        return ">>"
    if mv is None:
        return "τ"
    # Transition object
    if hasattr(mv, "label"):
        return mv.label if mv.label is not None else "τ"
    s = str(mv)
    return "τ" if s in ("None", "τ") else s

def is_tau(mv):
    """True if mv is a silent move (None label / None / 'None' / 'τ')."""
    if mv is None:
        return True
    if hasattr(mv, "label") and mv.label is None:
        return True
    s = str(mv)
    return s in ("None", "τ")

def format_alignment_two_rows_clean(aln_dict, sep=" | ", left_pad=2, hide_tau_only=True):
    pairs = aln_dict.get("alignment", [])

    filtered = []
    for (log_mv, model_mv) in pairs:
        # Recommended: hide only pure silent-routing columns (>> / τ)
        if hide_tau_only:
            if log_mv == ">>" and is_tau(model_mv):
                continue
        else:
            # Hide any column where model is τ
            if is_tau(model_mv):
                continue
        filtered.append((log_mv, model_mv))

    log_cells = [mv_to_str(l) for (l, m) in filtered]
    model_cells = [mv_to_str(m) for (l, m) in filtered]

    widths = [max(len(log_cells[i]), len(model_cells[i])) for i in range(len(filtered))]
    log_cells = [log_cells[i].ljust(widths[i]) for i in range(len(filtered))]
    model_cells = [model_cells[i].ljust(widths[i]) for i in range(len(filtered))]

    log_prefix = "LOG   :".ljust(left_pad + 7)
    model_prefix = "MODEL :".ljust(left_pad + 7)

    log_line = (" " * left_pad) + log_prefix + sep.join(log_cells)
    model_line = (" " * left_pad) + model_prefix + sep.join(model_cells)

    ruler_len = max(len(log_line), len(model_line))
    ruler_line = (" " * left_pad) + "-" * (ruler_len - left_pad)

    return log_line, model_line, ruler_line

def print_alignment_clean(aln_dict, label="γ", sep=" | ", hide_tau_only=True):
    log_line, model_line, ruler = format_alignment_two_rows_clean(
        aln_dict, sep=sep, hide_tau_only=hide_tau_only
    )
    print(f"{label} =")
    print(log_line)
    print(model_line)
    print(ruler)

# %% [markdown]
# ## Alingments (Hidden tau)

# %%
if "aligned" in state and state["aligned"] is not None and len(state["aligned"]) > 0:
    for i, a in enumerate(state["aligned"], start=1):
        print_alignment_clean(a, label=f"γ{i}", hide_tau_only=True)
else:
    print("Aligned data not available. Please run the 'Simulate + Align' button first.")
# Out:
# γ1 =
#   LOG   :  >>  | T9 | T7 | T8 | T6 | T6 | T11
#   MODEL :  T10 | T9 | T7 | T8 | T6 | T6 | T11
#   -------------------------------------------
# γ2 =
#   LOG   :  >>  | >> | T8 | T7 | T6 | T7
#   MODEL :  T10 | T9 | T8 | T7 | T6 | >>
#   -------------------------------------
# γ3 =
#   LOG   :  T10 | >> | T7 | T8 | T11 | T11 | T7
#   MODEL :  T10 | T9 | T7 | T8 | T11 | T11 | >>
#   --------------------------------------------
# γ4 =
#   LOG   :  T10 | T7 | T8 | T9 | T6 | T11 | T11
#   MODEL :  T10 | T7 | T8 | T9 | T6 | T11 | T11
#   --------------------------------------------
# γ5 =
#   LOG   :  T10 | T9 | T7 | T8 | T11
#   MODEL :  T10 | T9 | T7 | T8 | T11
#   ---------------------------------
# γ6 =
#   LOG   :  T10 | >> | T7 | T8 | T6
#   MODEL :  T10 | T9 | T7 | T8 | T6
#   --------------------------------
# γ7 =
#   LOG   :  T10 | T8 | T9 | T7 | T6
#   MODEL :  T10 | T8 | T9 | T7 | T6
#   --------------------------------
# γ8 =
# ...

# %% [markdown]
# ## Cost-Optimal Alignments with respect the Process model (PM)

# %%
from pm4py.algo.conformance.alignments.petri_net import algorithm as align_algo
from pm4py.algo.conformance.alignments.petri_net.algorithm import Parameters

# --- pick the right parameter name for trace costs (version-safe) ---
TRACE_COSTS_KEY = getattr(Parameters, "PARAM_TRACE_NET_COSTS", None)
if TRACE_COSTS_KEY is None:
    # fallback used in some versions
    TRACE_COSTS_KEY = getattr(Parameters, "TRACE_NET_COSTS", "trace_net_costs")

# --- model move costs: visible=1, tau(label None)=0 ---
model_cost_function = {t: (0 if t.label is None else 1) for t in net.transitions}

# --- sync costs: always 0 ---
sync_cost_function = {t: 0 for t in net.transitions}

# As log is a locale variable in on run, (recall it)

log = state.get("log")
if log is None:
    raise RuntimeError("No log found. Click 'Simulate + Align' first.")

aligned_custom = []
for trace in log:
    trace_costs = [1] * len(trace)  # log-move cost per event = 1
    params = {
        TRACE_COSTS_KEY: trace_costs,
        Parameters.PARAM_MODEL_COST_FUNCTION: model_cost_function,
        Parameters.PARAM_SYNC_COST_FUNCTION: sync_cost_function,
    }
    aligned_custom.append(align_algo.apply_trace(trace, net, im, fm, parameters=params))

# --- take the 10 lowest-cost optimal alignments across traces ---
ranked = sorted(
    [(i, a.get("cost", float("inf")), a) for i, a in enumerate(aligned_custom)],
    key=lambda x: x[1]
)[:10]

# --- print each with its cost ---
for rank, (case_idx, cost, a) in enumerate(ranked, start=1):
    print(f"Top {rank}: case={case_idx}, cost={cost}, fitness={a.get('fitness')}")
    print_alignment_clean(a, label=f"γ(case {case_idx})", hide_tau_only=True)
# Out:
# Top 1: case=4, cost=0, fitness=1.0
# γ(case 4) =
#   LOG   :  T10 | T8 | T7 | T9 | T6 | T6 | T11 | T11
#   MODEL :  T10 | T8 | T7 | T9 | T6 | T6 | T11 | T11
#   -------------------------------------------------
# Top 2: case=6, cost=0, fitness=1.0
# γ(case 6) =
#   LOG   :  T10 | T7 | T9 | T8 | T6 | T11 | T6
#   MODEL :  T10 | T7 | T9 | T8 | T6 | T11 | T6
#   -------------------------------------------
# Top 3: case=7, cost=0, fitness=1.0
# γ(case 7) =
#   LOG   :  T10 | T7 | T8 | T9 | T11 | T11
#   MODEL :  T10 | T7 | T8 | T9 | T11 | T11
#   ---------------------------------------
# Top 4: case=8, cost=0, fitness=1.0
# γ(case 8) =
#   LOG   :  T10 | T7 | T9 | T8 | T11 | T11
#   MODEL :  T10 | T7 | T9 | T8 | T11 | T11
#   ---------------------------------------
# Top 5: case=12, cost=0, fitness=1.0
# γ(case 12) =
#   LOG   :  T10 | T9 | T8 | T7 | T11
#   MODEL :  T10 | T9 | T8 | T7 | T11
#   ---------------------------------
# Top 6: case=13, cost=0, fitness=1.0
# γ(case 13) =
# ...

# %% [markdown]
# # Goal-Oriented Compliance Analysis at Design-time

# %% [markdown]
# ## Case dimensions
#
# We classify traces along two axes:
#
# | Dimension     | Meaning                     |
# | ------------- | --------------------------- |
# | PM compliance | alignment cost = 0          |
# | GM compliance | goal satisfaction = True    |
# | Complete     | marking ∈ final marking set |
#
# So we compute: PM ∈ {T,F}, GM ∈ {T,F}, FINAL ∈ {T,F}. So, we have 8 cases.

# %%
#Helpers
def is_pm_compliant(aln):
    return aln.get("cost", 1) == 0

def is_finalized(aln):
    return aln.get("is_fit", False) or aln.get("fitness",0)==1.0

def is_gm_compliant(trace):
    # YOU plug your goal-evaluation function here
    return evaluate_goals(trace)  # boolean

# %%
# Case Classifier
def classify_case(trace, aln):
    PM = is_pm_compliant(aln)
    GM = is_gm_compliant(trace)
    FIN = is_finalized(aln)

    return (PM, GM, FIN)

# %% [markdown]
# # Complete Trace

# %% [markdown]
# ## Case 0F — FINALIZED + PM✓ + GM✓ - Correct execution
# Trace fits the process model and satisfies goals.
#
#
# *   Interpretation: nothing to repair. Execution is both structurally and semantically correct.
# *   Alingment Pattern: Only synchronous moves.
# *   Cost = 0
# *   Repair = None

# %% [markdown]
# ## Case 1F — — FINALIZED + PM✗ + GM✓
#
#
#
# Trace violates process structure but still satisfies goals.
#
#
# *   Interpretation: Model is too strict.
# *   Alingment Pattern: Only synchronous moves.
# *   Cost >0 => Actual cost should be 0 — process model is weak wrt goal mode
# *   Repair = Options below
#
#         1. Remove superfluous constraints
#         2. Allow optional path
#         3. Relax ordering arcs

# %% [markdown]
# ## Case 2F — FINALIZED + PM✓ + GM✗
#
#
# Process execution valid but goals violated.
#
#
# *   Interpretation: cost measures semantic incompleteness
#
# GoCC-Alignments.drawio
# *   Alingment Pattern: Only synchronous moves.
# *   Cost =0 =>  should be more than 0 minimal goal-achievement completion distance
# *   Repair = Options below
#
#         1. Remove superfluous constraints
#         2. *Inject* or enforce goal-support activities.

# %% [markdown]
# ## Case 3F — FINALIZED + PM✗ + GM✗
#
#
# Process execution valid but goals violated.
#
#
# *   Interpretation: Execution wrong + goals violated.
#
# GoCC-Alignments.drawio
# *   Alingment Pattern: Only synchronous moves.
# *   Cost =0 =>  should be more than 0 minimal goal-achievement completion distance
# *   Repair = Options below
#
#         1. fix control flow
#         2. *add* goal-support steps
